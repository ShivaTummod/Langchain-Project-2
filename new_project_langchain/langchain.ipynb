# %%
1+1
# Out:
# 2

# %%
from langchain.llms import OpenAI

# %%
import os
os.environ["OPEN_API_KEY"]="openai_key"

# %%
llm=OpenAI(temperature=0.6)

# %%
"""text = "What Is A Capital Of India"
print(llm.predict(text))"""
#output: Delhi
# Out:
# 'text = "What Is A Capital Of India"\nprint(llm.predict(text))'

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain_huggingface import HuggingFaceEndpoint
import os
llm_huggingface = HuggingFaceEndpoint(
    repo_id="bigscience/bloom",  # or any text-generation model
    temperature=0.5
)

# %%
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[22], line 13
#       7 llm_huggingface = HuggingFaceEndpoint(
#       8     repo_id="bigscience/bloom",  # or any text-generation model
#       9     temperature=0.5
#      10 )
#      12 # Call the model
# ---> 13 output = llm_huggingface.invoke("What is the capital of Russia?")
#      14 print(output)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
# ...
