# %%
import streamlit as st
from transformers import MarianMTModel, MarianTokenizer

# %%
model_name = "Helsinki-NLP/opus-mt-en-hi"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(mocel_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 model_name = "Helsinki-NLP/opus-mt-en-hi"
# ----> 2 tokenizer = MarianTokenizer.from_pretrained(model_name)
#       3 model = MarianMTModel.from_pretrained(mocel_name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:1885, in DummyObject.__getattribute__(cls, key)
#    1883 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    1884     return super().__getattribute__(key)
# -> 1885 requires_backends(cls, cls._backends)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:1871, in requires_backends(obj, backends)
#    1868         failed.append(msg.format(name))
#    1870 if failed:
# -> 1871     raise ImportError("".join(failed))
#
# ImportError:
# MarianTokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.
