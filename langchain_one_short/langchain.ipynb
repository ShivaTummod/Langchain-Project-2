# %%
from langchain.llms import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.llms import OpenAI
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain\llms\__init__.py:545, in __getattr__(name)
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     547     # If not in interactive env, raise warning.
#     548     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
import os
os.environ["OPEN_API_KEY"] ="9fb4fa856a3e4c6894f7f620d62616c8"

# %%
llm = OpenAI(temperature=0.7)

# %%
''' text = "what is capital of india"
 print(llm.predict(text))'''
# Out:
# 'text = "what is capital of india"\nprint(llm.predict(text))'

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain import HuggingFaceHub
llm_huggingface=HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={"temperature":0,"max_length":64})

# %%
output = llm_huggingface.predict("can you tell me capital of Russia")
print(output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 output = llm_huggingface.predict("can you tell me capital of Russia")
#       2 print(output)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\llms.py:1356, in BaseLLM.predict(self, text, stop, **kwargs)
#    1350 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1351 @override
#    1352 def predict(
#    1353     self, text: str, *, stop: Optional[Sequence[str]] = None, **kwargs: Any
#    1354 ) -> str:
#    1355     _stop = None if stop is None else list(stop)
# ...
