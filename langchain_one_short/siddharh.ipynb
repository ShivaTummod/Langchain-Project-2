# %%
user_input = "Tell me a Joke"
user_input.title
print(user_input)
# Out:
# Tell me a Joke

# %%
user_input = "tell me a Joke"
reaponse = llm.generate(user_input)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 user_input = "tell me a Joke"
# ----> 2 reaponse = llm.generate(user_input)
#       3 print(response)
#
# NameError: name 'llm' is not defined

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo")
response = llm.predict("Explain gravity in simple words")
print(response)
